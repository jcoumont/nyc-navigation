# %% [markdown]
# ## OSMNX from file

# %%
import osmnx as ox
import momepy
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import folium
from IPython.display import IFrame
# Out:
# /Users/jeromecoumont/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:84: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   warnings.warn(

# %%
G=ox.load_graphml(filepath='data/NYC_drive.osm')

# %%
nodes_proj, edges_proj = ox.graph_to_gdfs(G, nodes=True, edges=True)

# %%
print(nodes_proj.shape)
print(edges_proj.shape)
# Out:
# (55361, 6)
# (140812, 15)

# %%
edges_proj.head()
# Out:
#                                                   osmid  oneway  \
# u        v         key
# 39076461 42854803  0                           25161578    True
#          274283981 0              [122633397, 25161349]    True
# 39076490 277672046 0                            5699971    True
#          277672005 0                           39084898    True
# 39076504 462124701 0    [618709517, 618709515, 5700693]    True
#
#                               highway   length  \
# u        v         key
# 39076461 42854803  0    motorway_link  254.709
#          274283981 0         motorway  767.800
# 39076490 277672046 0    motorway_link  259.674
#          277672005 0         motorway  291.839
# 39076504 462124701 0    motorway_link  433.148
#
#                                                                  geometry  \
# u        v         key
# 39076461 42854803  0    LINESTRING (-73.79463 40.78641, -73.79361 40.7...
#          274283981 0    LINESTRING (-73.79463 40.78641, -73.79309 40.7...
# 39076490 277672046 0    LINESTRING (-73.75709 40.76243, -73.75721 40.7...
#          277672005 0    LINESTRING (-73.75709 40.76243, -73.75741 40.7...
# 39076504 462124701 0    LINESTRING (-73.74416 40.75347, -73.74453 40.7...
#
#                        lanes  ref                  name maxspeed bridge  \
# u        v         key
# 39076461 42854803  0     NaN  NaN                   NaN      NaN    NaN
#          274283981 0       2  CIP  Cross Island Parkway   50 mph    NaN
# 39076490 277672046 0     NaN  NaN                   NaN      NaN    NaN
#          277672005 0       3  CIP  Cross Island Parkway   50 mph    NaN
# 39076504 462124701 0       1  NaN                   NaN      NaN    yes
#
#                        access tunnel width junction service
# u        v         key
# 39076461 42854803  0      NaN    NaN   NaN      NaN     NaN
#          274283981 0      NaN    NaN   NaN      NaN     NaN
# 39076490 277672046 0      NaN    NaN   NaN      NaN     NaN
#          277672005 0      NaN    NaN   NaN      NaN     NaN
# 39076504 462124701 0      NaN    NaN   NaN      NaN     NaN

# %%
edges_proj.head()
# Out:
#                                                   osmid  oneway  \
# u        v         key
# 39076461 42854803  0                           25161578    True
#          274283981 0              [122633397, 25161349]    True
# 39076490 277672046 0                            5699971    True
#          277672005 0                           39084898    True
# 39076504 462124701 0    [618709517, 618709515, 5700693]    True
#
#                               highway   length  \
# u        v         key
# 39076461 42854803  0    motorway_link  254.709
#          274283981 0         motorway  767.800
# 39076490 277672046 0    motorway_link  259.674
#          277672005 0         motorway  291.839
# 39076504 462124701 0    motorway_link  433.148
#
#                                                                  geometry  \
# u        v         key
# 39076461 42854803  0    LINESTRING (-73.79463 40.78641, -73.79361 40.7...
#          274283981 0    LINESTRING (-73.79463 40.78641, -73.79309 40.7...
# 39076490 277672046 0    LINESTRING (-73.75709 40.76243, -73.75721 40.7...
#          277672005 0    LINESTRING (-73.75709 40.76243, -73.75741 40.7...
# 39076504 462124701 0    LINESTRING (-73.74416 40.75347, -73.74453 40.7...
#
#                        lanes  ref                  name maxspeed bridge  \
# u        v         key
# 39076461 42854803  0     NaN  NaN                   NaN      NaN    NaN
#          274283981 0       2  CIP  Cross Island Parkway   50 mph    NaN
# 39076490 277672046 0     NaN  NaN                   NaN      NaN    NaN
#          277672005 0       3  CIP  Cross Island Parkway   50 mph    NaN
# 39076504 462124701 0       1  NaN                   NaN      NaN    yes
#
#                        access tunnel width junction service
# u        v         key
# 39076461 42854803  0      NaN    NaN   NaN      NaN     NaN
#          274283981 0      NaN    NaN   NaN      NaN     NaN
# 39076490 277672046 0      NaN    NaN   NaN      NaN     NaN
#          277672005 0      NaN    NaN   NaN      NaN     NaN
# 39076504 462124701 0      NaN    NaN   NaN      NaN     NaN

# %% [markdown]
# #### Insert here the weigth management

# %%
edges_proj["dangerosity"]=edges_proj["length"]%1

# %%
edges_proj.head()
# Out:
#                                                   osmid  oneway  \
# u        v         key
# 39076461 42854803  0                           25161578    True
#          274283981 0              [122633397, 25161349]    True
# 39076490 277672046 0                            5699971    True
#          277672005 0                           39084898    True
# 39076504 462124701 0    [618709517, 618709515, 5700693]    True
#
#                               highway   length  \
# u        v         key
# 39076461 42854803  0    motorway_link  254.709
#          274283981 0         motorway  767.800
# 39076490 277672046 0    motorway_link  259.674
#          277672005 0         motorway  291.839
# 39076504 462124701 0    motorway_link  433.148
#
#                                                                  geometry  \
# u        v         key
# 39076461 42854803  0    LINESTRING (-73.79463 40.78641, -73.79361 40.7...
#          274283981 0    LINESTRING (-73.79463 40.78641, -73.79309 40.7...
# 39076490 277672046 0    LINESTRING (-73.75709 40.76243, -73.75721 40.7...
#          277672005 0    LINESTRING (-73.75709 40.76243, -73.75741 40.7...
# 39076504 462124701 0    LINESTRING (-73.74416 40.75347, -73.74453 40.7...
#
#                        lanes  ref                  name maxspeed bridge  \
# u        v         key
# 39076461 42854803  0     NaN  NaN                   NaN      NaN    NaN
#          274283981 0       2  CIP  Cross Island Parkway   50 mph    NaN
# 39076490 277672046 0     NaN  NaN                   NaN      NaN    NaN
#          277672005 0       3  CIP  Cross Island Parkway   50 mph    NaN
# 39076504 462124701 0       1  NaN                   NaN      NaN    yes
#
#                        access tunnel width junction service  dangerosity
# u        v         key
# 39076461 42854803  0      NaN    NaN   NaN      NaN     NaN        0.709
#          274283981 0      NaN    NaN   NaN      NaN     NaN        0.800
# 39076490 277672046 0      NaN    NaN   NaN      NaN     NaN        0.674
#          277672005 0      NaN    NaN   NaN      NaN     NaN        0.839
# 39076504 462124701 0      NaN    NaN   NaN      NaN     NaN        0.148

# %% [markdown]
# #### Recreate the nx map

# %%
G_weight = ox.graph_from_gdfs(nodes_proj, edges_proj)

# %% [markdown]
# !!!! Resauver le fichier en NYC_STREET_WEIGTH.OSM

# %%
G_weight.number_of_nodes()
# Out:
# 55361

# %%
G_weight.number_of_edges()
# Out:
# 140812

# %% [markdown]
# #### Compute route

# %%
origin_node = list(G_weight.nodes())[5000]
destination_node = list(G_weight.nodes())[55000]
route = nx.dijkstra_path(G_weight, origin_node, destination_node, weight="length")

# %%
len(route)
# Out:
# 350

# %%
#def get_path_weigth(u, v, d):
#    return 10

# %%
#route_weigth = nx.dijkstra_path(G_weight, origin_node, destination_node, weight=get_path_weigth)

# %%
route_weigth = nx.dijkstra_path(G_weight, origin_node, destination_node, weight="dangerosity")

# %%
len(route_weigth)
# Out:
# 100

# %%
G_route = G_weight.subgraph(route)
print(G_route.number_of_edges())
print(G_route.number_of_nodes())
# Out:
# 623
# 350

# %%
G_route = G_weight.subgraph(route_weigth)
print(G_route.number_of_edges())
print(G_route.number_of_nodes())
# Out:
# 117
# 100

# %%
node_pairs = zip(route_weigth[:-1], route_weigth[1:])
uvk = ((u, v, min(G_weight[u][v], key=lambda k: G_weight[u][v][k]["length"])) for u, v in node_pairs)

# %%
ox.graph_to_gdfs(G_weight.subgraph(route_weigth), nodes=False).loc[uvk].shape
# Out:
# (99, 13)

# %%
def get_route_detail(Graph, route_detail):
    node_pairs = zip(route_detail[:-1], route_detail[1:])
    uvk = ((u, v, min(Graph[u][v], key=lambda k: Graph[u][v][k]["length"])) for u, v in node_pairs)
    gdf_edges = ox.graph_to_gdfs(Graph.subgraph(route_detail), nodes=False).loc[uvk]
    return gdf_edges

# %%
route_detail = get_route_detail(G_weight, route_weigth)
#route_detail.to_csv('route.csv')
#route_detail.to_file("route.geojson", driver='GeoJSON')
#route_detail.to_file("route.shp")
#data=route_detail.to_file("file.geojson",driver='GeoJSON')
route_detail
# Out:
#                                         osmid  oneway      highway   length  \
# u          v          key
# 42497172   42478920   0             542167662    True  residential  216.911
# 42478920   42470278   0             275355364    True  residential   79.099
# 42470278   42478926   0             275355365    True  residential   82.184
# 42478926   42478932   0             275355368    True  residential   79.056
# 42478932   42478936   0             275355363    True  residential   80.610
# ...                                       ...     ...          ...      ...
# 43000947   43000955   0               5714674    True  residential  442.312
# 43000955   42948660   0             222788033   False     tertiary  130.780
# 42948660   42948672   0    [5711094, 5711095]   False  residential  269.509
# 42948672   5763432834 0               5715743   False  residential   69.550
# 5763432834 5763432833 0             608299208   False  residential   54.107
#
#                                                                     geometry  \
# u          v          key
# 42497172   42478920   0    LINESTRING (-73.88489 40.68081, -73.88537 40.6...
# 42478920   42470278   0    LINESTRING (-73.88538 40.68273, -73.88454 40.6...
# 42470278   42478926   0    LINESTRING (-73.88446 40.68286, -73.88350 40.6...
# 42478926   42478932   0    LINESTRING (-73.88350 40.68300, -73.88258 40.6...
# 42478932   42478936   0    LINESTRING (-73.88258 40.68313, -73.88165 40.6...
# ...                                                                      ...
# 43000947   43000955   0    LINESTRING (-74.21987 40.54658, -74.22073 40.5...
# 43000955   42948660   0    LINESTRING (-74.21889 40.54407, -74.21874 40.5...
# 42948660   42948672   0    LINESTRING (-74.21843 40.54295, -74.21859 40.5...
# 42948672   5763432834 0    LINESTRING (-74.22016 40.54181, -74.22042 40.5...
# 5763432834 5763432833 0    LINESTRING (-74.22095 40.54163, -74.22114 40.5...
#
#                           lanes  ref               name maxspeed bridge  \
# u          v          key
# 42497172   42478920   0     NaN  NaN       Elton Street      NaN    NaN
# 42478920   42470278   0     NaN  NaN   Ridgewood Avenue      NaN    NaN
# 42470278   42478926   0     NaN  NaN   Ridgewood Avenue      NaN    NaN
# 42478926   42478932   0     NaN  NaN   Ridgewood Avenue      NaN    NaN
# 42478932   42478936   0     NaN  NaN   Ridgewood Avenue      NaN    NaN
# ...                         ...  ...                ...      ...    ...
# 43000947   43000955   0     NaN  NaN      Lorraine Loop      NaN    NaN
# 43000955   42948660   0     NaN  NaN  Bloomingdale Road      NaN    NaN
# 42948660   42948672   0     NaN  NaN        Harris Lane      NaN    NaN
# 42948672   5763432834 0     NaN  NaN    Crabtree Avenue      NaN    NaN
# 5763432834 5763432833 0     NaN  NaN      Plumtree Lane      NaN    NaN
#
#                            dangerosity tunnel access
# u          v          key
# 42497172   42478920   0          0.911    NaN    NaN
# 42478920   42470278   0          0.099    NaN    NaN
# 42470278   42478926   0          0.184    NaN    NaN
# 42478926   42478932   0          0.056    NaN    NaN
# 42478932   42478936   0          0.610    NaN    NaN
# ...                                ...    ...    ...
# 43000947   43000955   0          0.312    NaN    NaN
# 43000955   42948660   0          0.780    NaN    NaN
# 42948660   42948672   0          0.509    NaN    NaN
# 42948672   5763432834 0          0.550    NaN    NaN
# 5763432834 5763432833 0          0.107    NaN    NaN
#
# [99 rows x 13 columns]

# %%
route_detail.to_csv('route.csv')

# %%
route_detail.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
from shapely import wkt

filename = "route.csv"
df = pd.read_csv(filename)
df['geometry'] = df['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df, geometry=df.geometry, crs = 'EPSG:4326' )
gdf
# Out:
#              u           v  key               osmid  oneway      highway  \
# 0     42497172    42478920    0           542167662    True  residential
# 1     42478920    42470278    0           275355364    True  residential
# 2     42470278    42478926    0           275355365    True  residential
# 3     42478926    42478932    0           275355368    True  residential
# 4     42478932    42478936    0           275355363    True  residential
# ..         ...         ...  ...                 ...     ...          ...
# 94    43000947    43000955    0             5714674    True  residential
# 95    43000955    42948660    0           222788033   False     tertiary
# 96    42948660    42948672    0  [5711094, 5711095]   False  residential
# 97    42948672  5763432834    0             5715743   False  residential
# 98  5763432834  5763432833    0           608299208   False  residential
#
#      length                                           geometry lanes  ref  \
# 0   216.911  LINESTRING (-73.88489 40.68081, -73.88537 40.6...   NaN  NaN
# 1    79.099  LINESTRING (-73.88538 40.68273, -73.88454 40.6...   NaN  NaN
# 2    82.184  LINESTRING (-73.88446 40.68286, -73.88350 40.6...   NaN  NaN
# 3    79.056  LINESTRING (-73.88350 40.68300, -73.88258 40.6...   NaN  NaN
# 4    80.610  LINESTRING (-73.88258 40.68313, -73.88165 40.6...   NaN  NaN
# ..      ...                                                ...   ...  ...
# 94  442.312  LINESTRING (-74.21987 40.54658, -74.22073 40.5...   NaN  NaN
# 95  130.780  LINESTRING (-74.21889 40.54407, -74.21874 40.5...   NaN  NaN
# 96  269.509  LINESTRING (-74.21843 40.54295, -74.21859 40.5...   NaN  NaN
# 97   69.550  LINESTRING (-74.22016 40.54181, -74.22042 40.5...   NaN  NaN
# 98   54.107  LINESTRING (-74.22095 40.54163, -74.22114 40.5...   NaN  NaN
#
#                  name maxspeed bridge  dangerosity tunnel access
# 0        Elton Street      NaN    NaN        0.911    NaN    NaN
# 1    Ridgewood Avenue      NaN    NaN        0.099    NaN    NaN
# 2    Ridgewood Avenue      NaN    NaN        0.184    NaN    NaN
# 3    Ridgewood Avenue      NaN    NaN        0.056    NaN    NaN
# 4    Ridgewood Avenue      NaN    NaN        0.610    NaN    NaN
# ..                ...      ...    ...          ...    ...    ...
# 94      Lorraine Loop      NaN    NaN        0.312    NaN    NaN
# 95  Bloomingdale Road      NaN    NaN        0.780    NaN    NaN
# 96        Harris Lane      NaN    NaN        0.509    NaN    NaN
# 97    Crabtree Avenue      NaN    NaN        0.550    NaN    NaN
# 98      Plumtree Lane      NaN    NaN        0.107    NaN    NaN
#
# [99 rows x 16 columns]

# %%
get_route_detail(G_weight, route)
# Out:
#                                osmid  oneway      highway   length  \
# u          v          key
# 42497172   42523328   0    277174501    True  residential   79.226
# 42523328   42502326   0    277174501    True  residential   79.018
# 42502326   42485145   0    277174501    True  residential   77.752
# 42485145   42504334   0    277174501    True  residential   76.000
# 42504334   42499692   0    277174501    True  residential   75.767
# ...                              ...     ...          ...      ...
# 43025031   43025043   0      5717363   False  residential   38.754
# 43025043   42952798   0      5715743   False  residential  111.499
# 42952798   42948672   0      5715743   False  residential   25.305
# 42948672   5763432834 0      5715743   False  residential   69.550
# 5763432834 5763432833 0    608299208   False  residential   54.107
#
#                                                                     geometry  \
# u          v          key
# 42497172   42523328   0    LINESTRING (-73.88489 40.68081, -73.88581 40.6...
# 42523328   42502326   0    LINESTRING (-73.88581 40.68067, -73.88674 40.6...
# 42502326   42485145   0    LINESTRING (-73.88674 40.68054, -73.88764 40.6...
# 42485145   42504334   0    LINESTRING (-73.88764 40.68040, -73.88852 40.6...
# 42504334   42499692   0    LINESTRING (-73.88852 40.68027, -73.88941 40.6...
# ...                                                                      ...
# 43025031   43025043   0    LINESTRING (-74.21847 40.54182, -74.21861 40.5...
# 43025043   42952798   0    LINESTRING (-74.21861 40.54215, -74.21987 40.5...
# 42952798   42948672   0    LINESTRING (-74.21987 40.54187, -74.22016 40.5...
# 42948672   5763432834 0    LINESTRING (-74.22016 40.54181, -74.22042 40.5...
# 5763432834 5763432833 0    LINESTRING (-74.22095 40.54163, -74.22114 40.5...
#
#                                        name  dangerosity lanes maxspeed  \
# u          v          key
# 42497172   42523328   0    Arlington Avenue        0.226   NaN      NaN
# 42523328   42502326   0    Arlington Avenue        0.018   NaN      NaN
# 42502326   42485145   0    Arlington Avenue        0.752   NaN      NaN
# 42485145   42504334   0    Arlington Avenue        0.000   NaN      NaN
# 42504334   42499692   0    Arlington Avenue        0.767   NaN      NaN
# ...                                     ...          ...   ...      ...
# 43025031   43025043   0       Crabtree Lane        0.754   NaN      NaN
# 43025043   42952798   0     Crabtree Avenue        0.499   NaN      NaN
# 42952798   42948672   0     Crabtree Avenue        0.305   NaN      NaN
# 42948672   5763432834 0     Crabtree Avenue        0.550   NaN      NaN
# 5763432834 5763432833 0       Plumtree Lane        0.107   NaN      NaN
#
#                           bridge junction  ref tunnel
# u          v          key
# 42497172   42523328   0      NaN      NaN  NaN    NaN
# 42523328   42502326   0      NaN      NaN  NaN    NaN
# 42502326   42485145   0      NaN      NaN  NaN    NaN
# 42485145   42504334   0      NaN      NaN  NaN    NaN
# 42504334   42499692   0      NaN      NaN  NaN    NaN
# ...                          ...      ...  ...    ...
# 43025031   43025043   0      NaN      NaN  NaN    NaN
# 43025043   42952798   0      NaN      NaN  NaN    NaN
# 42952798   42948672   0      NaN      NaN  NaN    NaN
# 42948672   5763432834 0      NaN      NaN  NaN    NaN
# 5763432834 5763432833 0      NaN      NaN  NaN    NaN
#
# [349 rows x 13 columns]

# %% [markdown]
# #### Plotting from gdf with folium

# %%
latitude = 40.677834
longitude = -74.012443
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=10)

folium.Marker([G.nodes[origin_node]['y'], G.nodes[origin_node]['x']], popup="<i>From</i>", icon=folium.Icon(color="green")).add_to(map_nyc)
folium.Marker([G.nodes[destination_node]['y'], G.nodes[destination_node]['x']], popup="<i>To</i>",icon=folium.Icon(color="red")).add_to(map_nyc)
folium.Choropleth(get_route_detail(G_weight, route), line_weight=5, line_color='blue', line_opacity=0.5).add_to(map_nyc)
folium.Choropleth(get_route_detail(G_weight, route_weigth),line_weight=5, line_color='red', line_opacity=0.5).add_to(map_nyc)

#folium.Choropleth(gdf["geometry"].loc[0],line_weight=5, line_color='red', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[1],line_weight=5, line_color='blue', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[2],line_weight=5, line_color='green', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[3],line_weight=5, line_color='yellow', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[4],line_weight=5, line_color='orange', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[5],line_weight=5, line_color='red', line_opacity=0.7).add_to(map_nyc)

#folium.Choropleth(gdf, line_weight=5, line_color='Red',line_opacity=0.7).add_to(map_nyc)

#folium.Choropleth(gdf, line_weight=5, "dangerosity" line_color='GnYlRd',line_opacity=0.7).add_to(map_nyc)
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8adf6542b86d44aaa3311c01c4b51c83%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8adf6542b86d44aaa3311c01c4b51c83%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8adf6542b86d44aaa3311c01c4b51c83%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8adf6542b86d44aaa3311c01c4b51c83%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
folium.Choropleth(get_route_detail(G_weight, route_weigth),line_weight=5, line_color='green', line_opacity=0.5).add_to(map_nyc)

map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8adf6542b86d44aaa3311c01c4b51c83%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8adf6542b86d44aaa3311c01c4b51c83%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8adf6542b86d44aaa3311c01c4b51c83%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8adf6542b86d44aaa3311c01c4b51c83%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
[G.nodes[origin_node]['x'], G.nodes[origin_node]['y']]
# Out:
# [-73.884893, 40.680811]

# %%
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8adf6542b86d44aaa3311c01c4b51c83%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8adf6542b86d44aaa3311c01c4b51c83%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8adf6542b86d44aaa3311c01c4b51c83%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8adf6542b86d44aaa3311c01c4b51c83%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
latitude = 40.677834
longitude = -74.012443
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=10)

folium.Marker([G.nodes[origin_node]['y'], G.nodes[origin_node]['x']], popup="<i>From</i>", icon=folium.Icon(color="green")).add_to(map_nyc)
folium.Marker([G.nodes[destination_node]['y'], G.nodes[destination_node]['x']], popup="<i>To</i>",icon=folium.Icon(color="red")).add_to(map_nyc)
gdf_short = get_route_detail(G_weight, route)
folium.Choropleth(gdf_short, line_weight=5, line_color='blue', line_opacity=0.5).add_to(map_nyc)
gdf_weigth = get_route_detail(G_weight, route_weigth)
folium.Choropleth(gdf_weigth, line_weight=5, line_color='red', line_opacity=0.5).add_to(map_nyc)

#folium.Choropleth(gdf["geometry"].loc[0],line_weight=5, line_color='red', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[1],line_weight=5, line_color='blue', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[2],line_weight=5, line_color='green', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[3],line_weight=5, line_color='yellow', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[4],line_weight=5, line_color='orange', line_opacity=0.5).add_to(map_nyc)
#folium.Choropleth(gdf["geometry"].loc[5],line_weight=5, line_color='red', line_opacity=0.7).add_to(map_nyc)

#folium.Choropleth(gdf, line_weight=5, line_color='Red',line_opacity=0.7).add_to(map_nyc)

#folium.Choropleth(gdf, line_weight=5, "dangerosity" line_color='GnYlRd',line_opacity=0.7).add_to(map_nyc)

tb = gdf_weigth.total_bounds
map_nyc.fit_bounds([(tb[1], tb[0]), (tb[3], tb[2])])
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9e3ce2bbab75433ca310a1e5f7de7682%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9e3ce2bbab75433ca310a1e5f7de7682%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9e3ce2bbab75433ca310a1e5f7de7682%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9e3ce2bbab75433ca310a1e5f7de7682%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

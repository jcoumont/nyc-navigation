# %%
import pandas as pd
import osmnx as ox
import folium
import geopandas as gpd
from shapely.geometry import Point
# Out:
# /Users/jeromecoumont/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:84: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ### Load risk

# %%
df_risk = pd.read_csv('../data/NYC_risk.csv', index_col=0)

# %%
df_risk.head()
# Out:
#     latitude  longitude  accidents  total_injured  total_killed
# 0  40.501465 -74.245230          1            0.0           0.0
# 1  40.503310 -74.237465          1            0.0           0.0
# 2  40.503387 -74.248830          1            0.0           0.0
# 3  40.503414 -74.244960          1            0.0           0.0
# 4  40.504470 -74.243454          1            0.0           0.0

# %%
geometry = [Point(xy) for xy in zip(df_risk.longitude, df_risk.latitude)]
gdf_risk = gpd.GeoDataFrame(df_risk, crs="EPSG:4326", geometry=geometry)

# %%
gdf_risk.head()
# Out:
#     latitude  longitude  accidents  total_injured  total_killed  \
# 0  40.501465 -74.245230          1            0.0           0.0
# 1  40.503310 -74.237465          1            0.0           0.0
# 2  40.503387 -74.248830          1            0.0           0.0
# 3  40.503414 -74.244960          1            0.0           0.0
# 4  40.504470 -74.243454          1            0.0           0.0
#
#                      geometry
# 0  POINT (-74.24523 40.50147)
# 1  POINT (-74.23747 40.50331)
# 2  POINT (-74.24883 40.50339)
# 3  POINT (-74.24496 40.50341)
# 4  POINT (-74.24345 40.50447)

# %% [markdown]
# ### Load graph

# %%
G = ox.load_graphml(filepath='../data/NYC_drive.osm')

# %%
G.number_of_nodes()
# Out:
# 55361

# %%
G.number_of_edges()
# Out:
# 140811

# %%
nodes_proj, edges_proj = ox.graph_to_gdfs(G, nodes=True, edges=True)

# %% [markdown]
# ### Create basic maps

# %%
latitude = 40.677834
longitude = -74.012443
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=10)
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f7682d5c091d4df087949d336f2aa88f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f7682d5c091d4df087949d336f2aa88f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f7682d5c091d4df087949d336f2aa88f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f7682d5c091d4df087949d336f2aa88f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Insert few markers

# %%
for i in range(5):
    folium.Marker([df_risk.iloc[i,0], df_risk.iloc[i,1]], popup=i, icon=folium.Icon(color="green")).add_to(map_nyc)

# %%
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f7682d5c091d4df087949d336f2aa88f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f7682d5c091d4df087949d336f2aa88f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f7682d5c091d4df087949d336f2aa88f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f7682d5c091d4df087949d336f2aa88f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Look after marker on lon/lat

# %%
nodes_proj.head()
# Out:
#                   y          x  ref            highway  street_count  \
# osmid
# 39076461  40.786409 -73.794627   33  motorway_junction             3
# 39076490  40.762429 -73.757091  31W  motorway_junction             3
# 39076504  40.753467 -73.744164  30W  motorway_junction             3
# 42421728  40.798048 -73.960044  NaN    traffic_signals             3
# 42421731  40.798645 -73.961474  NaN    traffic_signals             4
#
#                             geometry
# osmid
# 39076461  POINT (-73.79463 40.78641)
# 39076490  POINT (-73.75709 40.76243)
# 39076504  POINT (-73.74416 40.75347)
# 42421728  POINT (-73.96004 40.79805)
# 42421731  POINT (-73.96147 40.79865)

# %%
edges_proj.head()
# Out:
#                                                   osmid  oneway  \
# u        v         key
# 39076461 42854803  0                           25161578    True
#          274283981 0              [122633397, 25161349]    True
# 39076490 277672046 0                            5699971    True
#          277672005 0                           39084898    True
# 39076504 462124701 0    [618709517, 618709515, 5700693]    True
#
#                               highway   length  \
# u        v         key
# 39076461 42854803  0    motorway_link  254.709
#          274283981 0         motorway  767.800
# 39076490 277672046 0    motorway_link  259.674
#          277672005 0         motorway  291.839
# 39076504 462124701 0    motorway_link  433.148
#
#                                                                  geometry  \
# u        v         key
# 39076461 42854803  0    LINESTRING (-73.79463 40.78641, -73.79361 40.7...
#          274283981 0    LINESTRING (-73.79463 40.78641, -73.79309 40.7...
# 39076490 277672046 0    LINESTRING (-73.75709 40.76243, -73.75721 40.7...
#          277672005 0    LINESTRING (-73.75709 40.76243, -73.75741 40.7...
# 39076504 462124701 0    LINESTRING (-73.74416 40.75347, -73.74453 40.7...
#
#                        lanes  ref                  name maxspeed bridge  \
# u        v         key
# 39076461 42854803  0     NaN  NaN                   NaN      NaN    NaN
#          274283981 0       2  CIP  Cross Island Parkway   50 mph    NaN
# 39076490 277672046 0     NaN  NaN                   NaN      NaN    NaN
#          277672005 0       3  CIP  Cross Island Parkway   50 mph    NaN
# 39076504 462124701 0       1  NaN                   NaN      NaN    yes
#
#                        access tunnel width junction service
# u        v         key
# 39076461 42854803  0      NaN    NaN   NaN      NaN     NaN
#          274283981 0      NaN    NaN   NaN      NaN     NaN
# 39076490 277672046 0      NaN    NaN   NaN      NaN     NaN
#          277672005 0      NaN    NaN   NaN      NaN     NaN
# 39076504 462124701 0      NaN    NaN   NaN      NaN     NaN

# %%
for i in range(100):
    print(i)
    print(nodes_proj[(nodes_proj.y==df_risk.iloc[i,0]) & (nodes_proj.x==df_risk.iloc[i,1])])
    print(ox.get_nearest_node(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_dist=True))
# Out:
# 0
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42971016, 0.5073093519301438)
# 1
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (3658673953, 1.5886952720046006)
# 2
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989170, 2.1034914598947796)
# 3
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989156, 80.67459394037911)
# 4
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989145, 0.3560021870177833)
# 5
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989162, 83.2774066359121)
# 6
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42948879, 0.7609179464710885)
# 7
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989122, 0.4047526847174118)
# 8
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42959589, 0.591814224443054)
# 9
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42983709, 0.5384927192083909)
# 10
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43007069, 44.016530568475204)
# 11
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989117, 2.726495655916997)
# 12
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989117, 70.94009899869464)
# 13
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991670, 0.632206877931463)
# 14
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42985081, 0.676340515511279)
# 15
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42959581, 0.8526997474420535)
# 16
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42951337, 2.412663385480809)
# 17
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991645, 18.96018372506337)
# 18
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991641, 0.276929626576021)
# 19
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42985081, 496.82774802869613)
# 20
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42948864, 0.7927053611388848)
# 21
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42978564, 69.84183864868976)
# 22
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42978560, 15.113204247804262)
# 23
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42978557, 0.1690802977228735)
# 24
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42978548, 0.6321838301230667)
# 25
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (3148398079, 43.991881476066155)
# 26
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42975904, 69.1162883486912)
# 27
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991591, 0.538469908918571)
# 28
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43003516, 92.60690978156147)
# 29
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42984493, 2.0609758757262724)
# 30
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42978546, 0.5587287307982699)
# 31
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991586, 0.7926806813960854)
# 32
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43003516, 43.04257775563543)
# 33
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42979946, 33.989751035534766)
# 34
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43003569, 0.942895283447661)
# 35
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43013796, 39.98219168245554)
# 36
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42975901, 0.477620992431835)
# 37
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42994933, 0.6021148072900957)
# 38
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42975901, 88.672586919634)
# 39
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42994933, 47.941120155597076)
# 40
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42994933, 50.21448688606789)
# 41
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42950784, 20.531978126997767)
# 42
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42978538, 2.499378202809414)
# 43
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42962429, 92.5926140658244)
# 44
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42957292, 0.5538256901387966)
# 45
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42974281, 0.43705906239474585)
# 46
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43005877, 0.27691208140863277)
# 47
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42981785, 0.37398388178)
# 48
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42973538, 0.5538230508828712)
# 49
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42984482, 101.37643878311147)
# 50
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42989997, 2.7784841023920026)
# 51
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (3429342805, 3.318793063376121)
# 52
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42962429, 1.4403316120576937)
# 53
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42994069, 28.132433502500728)
# 54
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42984132, 2.7133707440940187)
# 55
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42968257, 9.917268089017906)
# 56
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43005856, 0.7997098461086074)
# 57
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42957387, 2.4914834764564087)
# 58
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991570, 3.2031701315123025)
# 59
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42959957, 27.81491244789958)
# 60
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42959848, 48.67727012979929)
# 61
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42949944, 0.3381297957786081)
# 62
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991570, 75.38515019850331)
# 63
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (6955288483, 3.414168255436338)
# 64
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991570, 99.87852830364915)
# 65
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43027901, 112.93827885007838)
# 66
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42959842, 9.461859369846719)
# 67
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42971237, 3.6283857978424794)
# 68
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42984466, 47.63216252536427)
# 69
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991500, 278.0285019270022)
# 70
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42983670, 4.363974749220224)
# 71
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42988996, 67.55028318853115)
# 72
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991518, 29.1558611885998)
# 73
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43003189, 0.43702409943187553)
# 74
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42988992, 0.852564296982264)
# 75
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42991460, 13.378140216978728)
# 76
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42951686, 41.10576105741409)
# 77
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43000925, 0.2768893757463647)
# 78
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43000925, 123.55244612603246)
# 79
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42992450, 33.2157272071133)
# 80
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43000929, 1.359350476628879)
# 81
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43000925, 102.25834880373634)
# 82
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42953330, 0.43701243151147345)
# 83
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42992448, 49.96066394643977)
# 84
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42984445, 1.3679062343211645)
# 85
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42981734, 34.84931626765163)
# 86
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42988907, 0.5537672837683033)
# 87
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43001097, 122.35325982143794)
# 88
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42960404, 2.4032230863555206)
# 89
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43001097, 49.19612010973073)
# 90
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42988898, 0.7118212790448979)
# 91
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43007000, 18.83867329994113)
# 92
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (43001119, 125.85548207936345)
# 93
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42980117, 6.197664805433195)
# 94
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42988894, 0.6135418663332941)
# 95
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42984434, 1.7207901800199514)
# 96
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (447832833, 8.26367050976746)
# 97
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42949914, 0.6852621862079258)
# 98
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (42972303, 1.0677188051132107)
# 99
# Empty GeoDataFrame
# Columns: [y, x, ref, highway, street_count, geometry]
# Index: []
# (447832829, 3.5329970009571143)

# %%
for i in range(5):
    node_id, distance = ox.get_nearest_node(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_dist=True)
    print(i, " - ", node_id, " - ", distance)
    folium.Marker([G.nodes[node_id]['y'], G.nodes[node_id]['x']], popup=f"{i}, distance = {distance}", icon=folium.Icon(color="red")).add_to(map_nyc)
# Out:
# 0  -  42971016  -  0.5073093519301438
# 1  -  3658673953  -  1.5886952720046006
# 2  -  42989170  -  2.1034914598947796
# 3  -  42989156  -  80.67459394037911
# 4  -  42989145  -  0.3560021870177833

# %%
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f7682d5c091d4df087949d336f2aa88f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f7682d5c091d4df087949d336f2aa88f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f7682d5c091d4df087949d336f2aa88f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f7682d5c091d4df087949d336f2aa88f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Test one or more specific points

# %%
latitude = 40.677834
longitude = -74.012443
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=10)

index = [70,
93,
96,
66,
55,
75,
22]

for i in index:
    node_id, distance = ox.get_nearest_node(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_dist=True)
    print(i, " - ", node_id, " - ", distance)
    folium.Marker([df_risk.iloc[i,0], df_risk.iloc[i,1]], popup=i, icon=folium.Icon(color="green")).add_to(map_nyc)
    folium.Marker([G.nodes[node_id]['y'], G.nodes[node_id]['x']], popup=f"{i}, distance = {distance}", icon=folium.Icon(color="red")).add_to(map_nyc)
map_nyc
# Out:
# 70  -  42983670  -  4.363974749220224
# 93  -  42980117  -  6.197664805433195
# 96  -  447832833  -  8.26367050976746
# 66  -  42959842  -  9.461859369846719
# 55  -  42968257  -  9.917268089017906
# 75  -  42991460  -  13.378140216978728
# 22  -  42978560  -  15.113204247804262
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4a9038fd16f74e2eacf6ed19d9d0662e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4a9038fd16f74e2eacf6ed19d9d0662e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4a9038fd16f74e2eacf6ed19d9d0662e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4a9038fd16f74e2eacf6ed19d9d0662e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### TRY TO FIND THE EDGE

# %%
distance_limit = 10

for i in range(10):
    node_id, distance = ox.get_nearest_node(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_dist=True)
    if distance >= distance_limit:
        print(i, " - ", node_id, " - ", distance)
        # ATTENTION - X / Y ici et non Y / X
        nearest_edge = ox.get_nearest_edge(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_geom=True, return_dist=True)
        print(nearest_edge)
        edge = G.edges[nearest_edge[0], nearest_edge[1], nearest_edge[2]]
        print(edge)
# Out:
# 3  -  42989156  -  80.67459394037911
# (42989156, 42991087, 0, <shapely.geometry.linestring.LineString object at 0x16838fc70>, 7.712209202418146e-07)
# {'osmid': 68665158, 'name': 'Main Street', 'highway': 'residential', 'oneway': False, 'length': 285.641}
# 5  -  42989162  -  83.2774066359121
# (42989162, 42951353, 0, <shapely.geometry.linestring.LineString object at 0x16bc06250>, 6.096998575547062e-07)
# {'osmid': 744313477, 'name': 'Carteret Street', 'highway': 'residential', 'oneway': False, 'length': 292.61}

# %%
from datetime import datetime

# %%
print(f"[!] Start Loading: {datetime.now()}")
distance_limit = 10

latitude = 40.677834
longitude = -74.012443
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=10)

for i in range(100):
    node_id, distance = ox.get_nearest_node(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_dist=True)
    if distance >= distance_limit:
        print(i, " - ", node_id, " - ", distance)
        # ATTENTION - X / Y ici et non Y / X
        nearest_edge = ox.get_nearest_edge(G, (df_risk.iloc[i,0], df_risk.iloc[i,1]), return_geom=True, return_dist=True)
        print(nearest_edge)
        #edge = G.edges[nearest_edge[0], nearest_edge[1], nearest_edge[2]]
        #print(edge)
        folium.Marker([df_risk.iloc[i,0], df_risk.iloc[i,1]], popup=i, icon=folium.Icon(color="green")).add_to(map_nyc)
        folium.Choropleth(nearest_edge[3], popup=f"{i}, distance = {distance}", line_weight=5, line_color='red', line_opacity=0.5).add_to(map_nyc)
        print(f"[!] End loading edge: {datetime.now()}")
print(f"[!] End Loading: {datetime.now()}")
map_nyc
# Out:
# [!] Start Loading: 2021-01-10 18:05:40.841507
# 3  -  42989156  -  80.67459394037911
# (42989156, 42991087, 0, <shapely.geometry.linestring.LineString object at 0x1527dca60>, 7.712209202418146e-07)
# [!] End loading edge: 2021-01-10 18:06:21.834876
# 5  -  42989162  -  83.2774066359121
# (42989162, 42951353, 0, <shapely.geometry.linestring.LineString object at 0x1530d4850>, 6.096998575547062e-07)
# [!] End loading edge: 2021-01-10 18:06:57.890046
# 10  -  43007069  -  44.016530568475204
# (43007069, 43007072, 0, <shapely.geometry.linestring.LineString object at 0x152e31220>, 7.220663124792896e-06)
# [!] End loading edge: 2021-01-10 18:07:37.019785
# 12  -  42989117  -  70.94009899869464
# (42976153, 42989117, 0, <shapely.geometry.linestring.LineString object at 0x1530289a0>, 3.249035753732037e-05)
# [!] End loading edge: 2021-01-10 18:08:15.046316
# 17  -  42991645  -  18.96018372506337
# (42960083, 42991645, 0, <shapely.geometry.linestring.LineString object at 0x153028070>, 8.785090065968767e-06)
# [!] End loading edge: 2021-01-10 18:08:51.147884
# 19  -  42985081  -  496.82774802869613
# (42985081, 42984493, 0, <shapely.geometry.linestring.LineString object at 0x152e4cfa0>, 4.9189281478695515e-06)
# [!] End loading edge: 2021-01-10 18:09:21.754028
# 21  -  42978564  -  69.84183864868976
# (42978564, 42976280, 0, <shapely.geometry.linestring.LineString object at 0x152f04f10>, 8.127127302598898e-06)
# [!] End loading edge: 2021-01-10 18:09:52.281261
# 22  -  42978560  -  15.113204247804262
# (42978557, 42978560, 0, <shapely.geometry.linestring.LineString object at 0x15271f7f0>, 2.4426938530125822e-06)
# [!] End loading edge: 2021-01-10 18:10:21.309770
# 25  -  3148398079  -  43.991881476066155
# (43003516, 3148398080, 0, <shapely.geometry.linestring.LineString object at 0x152d094c0>, 1.491600610739645e-05)
# [!] End loading edge: 2021-01-10 18:10:51.102888
# 26  -  42975904  -  69.1162883486912
# (42975904, 42991591, 0, <shapely.geometry.linestring.LineString object at 0x152cba8e0>, 3.880256920253935e-06)
# [!] End loading edge: 2021-01-10 18:11:21.007564
# 28  -  43003516  -  92.60690978156147
# (43003516, 3148398080, 0, <shapely.geometry.linestring.LineString object at 0x15294edc0>, 1.674123300993104e-05)
# [!] End loading edge: 2021-01-10 18:11:50.255208
# 32  -  43003516  -  43.04257775563543
# (43003516, 3148398080, 0, <shapely.geometry.linestring.LineString object at 0x152badd90>, 2.1282110379677394e-05)
# [!] End loading edge: 2021-01-10 18:12:19.760164
# 33  -  42979946  -  33.989751035534766
# (42979946, 43003569, 0, <shapely.geometry.linestring.LineString object at 0x152b23280>, 5.573965839845298e-06)
# [!] End loading edge: 2021-01-10 18:12:50.224008
# 35  -  43013796  -  39.98219168245554
# (43013796, 42991575, 0, <shapely.geometry.linestring.LineString object at 0x152b35df0>, 4.094394573540219e-06)
# [!] End loading edge: 2021-01-10 18:13:19.089230
# 38  -  42975901  -  88.672586919634
# (42975898, 42975901, 0, <shapely.geometry.linestring.LineString object at 0x152a08160>, 7.462355800052666e-06)
# [!] End loading edge: 2021-01-10 18:13:51.288367
# 39  -  42994933  -  47.941120155597076
# (42950784, 42994933, 0, <shapely.geometry.linestring.LineString object at 0x15298c8e0>, 4.164121383995619e-06)
# [!] End loading edge: 2021-01-10 18:14:20.831197
# 40  -  42994933  -  50.21448688606789
# (42976583, 42994933, 0, <shapely.geometry.linestring.LineString object at 0x1529983a0>, 5.165399135419008e-06)
# [!] End loading edge: 2021-01-10 18:14:50.904610
# 41  -  42950784  -  20.531978126997767
# (42950784, 42994933, 0, <shapely.geometry.linestring.LineString object at 0x152825700>, 9.406498190571082e-06)
# [!] End loading edge: 2021-01-10 18:15:19.661133
# 43  -  42962429  -  92.5926140658244
# (42978540, 42962429, 0, <shapely.geometry.linestring.LineString object at 0x152580040>, 1.3664923849116197e-06)
# [!] End loading edge: 2021-01-10 18:15:48.701790
# 49  -  42984482  -  101.37643878311147
# (42984482, 42984493, 0, <shapely.geometry.linestring.LineString object at 0x1526e2820>, 2.9899851404394912e-05)
# [!] End loading edge: 2021-01-10 18:16:18.237189
# 53  -  42994069  -  28.132433502500728
# (42975898, 42994069, 0, <shapely.geometry.linestring.LineString object at 0x152530940>, 1.1868600394064501e-05)
# [!] End loading edge: 2021-01-10 18:16:50.391426
# 59  -  42959957  -  27.81491244789958
# (43002970, 42959957, 0, <shapely.geometry.linestring.LineString object at 0x151cdf4f0>, 1.9996174084285683e-05)
# [!] End loading edge: 2021-01-10 18:17:22.593189
# 60  -  42959848  -  48.67727012979929
# (42953163, 42959848, 0, <shapely.geometry.linestring.LineString object at 0x1521a8f70>, 9.872507980024679e-06)
# [!] End loading edge: 2021-01-10 18:17:51.725921
# 62  -  42991570  -  75.38515019850331
# (42991570, 43000925, 0, <shapely.geometry.linestring.LineString object at 0x1521bb760>, 2.245926085007237e-05)
# [!] End loading edge: 2021-01-10 18:18:21.010886
# 64  -  42991570  -  99.87852830364915
# (42991570, 43000925, 0, <shapely.geometry.linestring.LineString object at 0x1520dd6a0>, 4.206987238158802e-05)
# [!] End loading edge: 2021-01-10 18:18:50.947678
# 65  -  43027901  -  112.93827885007838
# (42991570, 43000925, 0, <shapely.geometry.linestring.LineString object at 0x1520f50d0>, 2.4891193633067126e-05)
# [!] End loading edge: 2021-01-10 18:19:19.932818
# 68  -  42984466  -  47.63216252536427
# (42984472, 42984466, 0, <shapely.geometry.linestring.LineString object at 0x151fb84f0>, 1.6530570080209546e-05)
# [!] End loading edge: 2021-01-10 18:19:49.801988
# 69  -  42991500  -  278.0285019270022
# (42991500, 42992454, 0, <shapely.geometry.linestring.LineString object at 0x151e7d220>, 8.670006895790745e-06)
# [!] End loading edge: 2021-01-10 18:20:18.921776
# 71  -  42988996  -  67.55028318853115
# (42958506, 42988996, 0, <shapely.geometry.linestring.LineString object at 0x151e91220>, 1.1211053852897415e-05)
# [!] End loading edge: 2021-01-10 18:20:47.945518
# 72  -  42991518  -  29.1558611885998
# (42991518, 3566540125, 0, <shapely.geometry.linestring.LineString object at 0x151c82ca0>, 9.156307251640537e-06)
# [!] End loading edge: 2021-01-10 18:21:16.417638
# 75  -  42991460  -  13.378140216978728
# (392228682, 42991460, 0, <shapely.geometry.linestring.LineString object at 0x151c98e50>, 1.1822759462974842e-05)
# [!] End loading edge: 2021-01-10 18:21:47.341757
# 76  -  42951686  -  41.10576105741409
# (42951686, 42951696, 0, <shapely.geometry.linestring.LineString object at 0x151c871f0>, 2.0666631300127806e-05)
# [!] End loading edge: 2021-01-10 18:22:16.878820
# 78  -  43000925  -  123.55244612603246
# (43000925, 43000929, 0, <shapely.geometry.linestring.LineString object at 0x151a0dbe0>, 7.05471522196461e-05)
# [!] End loading edge: 2021-01-10 18:33:09.989765
# 79  -  42992450  -  33.2157272071133
# (42992448, 42992450, 0, <shapely.geometry.linestring.LineString object at 0x151704dc0>, 1.3316591415080941e-05)
# [!] End loading edge: 2021-01-10 18:33:49.891178
# 81  -  43000925  -  102.25834880373634
# (43000925, 43001097, 0, <shapely.geometry.linestring.LineString object at 0x151704b20>, 1.716726821386999e-05)
# [!] End loading edge: 2021-01-10 18:34:20.381690
# 83  -  42992448  -  49.96066394643977
# (42992450, 42992448, 0, <shapely.geometry.linestring.LineString object at 0x151864880>, 1.3450530607452687e-05)
# [!] End loading edge: 2021-01-10 18:34:49.252087
# 85  -  42981734  -  34.84931626765163
# (42981734, 42960393, 0, <shapely.geometry.linestring.LineString object at 0x151877490>, 1.5042223216113597e-05)
# [!] End loading edge: 2021-01-10 18:35:18.845222
# 87  -  43001097  -  122.35325982143794
# (43000925, 43001097, 0, <shapely.geometry.linestring.LineString object at 0x15172ac10>, 4.21172144047373e-06)
# [!] End loading edge: 2021-01-10 18:35:47.529955
# 89  -  43001097  -  49.19612010973073
# (43000925, 43001097, 0, <shapely.geometry.linestring.LineString object at 0x151c87100>, 8.372895408782448e-06)
# [!] End loading edge: 2021-01-10 18:36:16.296308
# 91  -  43007000  -  18.83867329994113
# (43007000, 42990688, 1, <shapely.geometry.linestring.LineString object at 0x151bb98e0>, 1.0215673197169391e-05)
# [!] End loading edge: 2021-01-10 18:36:45.419339
# 92  -  43001119  -  125.85548207936345
# (43000929, 43001119, 0, <shapely.geometry.linestring.LineString object at 0x1511f09d0>, 3.224568675330126e-05)
# [!] End loading edge: 2021-01-10 18:37:14.049294
# [!] End Loading: 2021-01-10 18:37:15.092185
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c1c7c06c06454feeb3860d72640ae924%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c1c7c06c06454feeb3860d72640ae924%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c1c7c06c06454feeb3860d72640ae924%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c1c7c06c06454feeb3860d72640ae924%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9b2abf8bb4654352b20884b7e79825ee%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9b2abf8bb4654352b20884b7e79825ee%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9b2abf8bb4654352b20884b7e79825ee%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9b2abf8bb4654352b20884b7e79825ee%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.677834%2C%20-74.012443%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Set the risk on the nodes

# %%
def compute_risk(accident, total_injured, total_killed):
    return accident + total_injured + (total_killed * 2)

# %%
print(f"[!] Start Loading: {datetime.now()}")
i = 0 

for idx, row in df_risk.iterrows():
    node_id, distance = ox.get_nearest_node(G, (row["latitude"], row["longitude"]), return_dist=True)
    if distance < 10:
        G.nodes[node_id]["accidents"] = G.nodes[node_id].get("accidents", 0) + row.accidents
        G.nodes[node_id]["total_injured"] = G.nodes[node_id].get("total_injured", 0) + row.total_injured
        G.nodes[node_id]["total_killed"] = G.nodes[node_id].get("total_killed", 0) + row.total_killed
        G.nodes[node_id]["risk"] = compute_risk(G.nodes[node_id]["accidents"], 
                                                G.nodes[node_id]["total_injured"], 
                                                G.nodes[node_id]["total_killed"])
    if idx % 100 == 0:
        print(f"[{idx}]: {datetime.now()}") 
    
print(f"[!] End Loading: {datetime.now()}") 
print(f"[!] Start save: {datetime.now()}")  
ox.save_graphml(G, filepath="NYC_drive_risk.osm")
print(f"[!] End save: {datetime.now()}")
# Out:
# [!] Start Loading: 2021-01-10 20:01:18.845965
# [0]: 2021-01-10 20:01:30.425571
# [100]: 2021-01-10 20:01:40.471692
# [200]: 2021-01-10 20:01:49.195064
# [300]: 2021-01-10 20:01:59.602559
# [400]: 2021-01-10 20:02:11.533356
# [500]: 2021-01-10 20:02:24.473952
# [600]: 2021-01-10 20:02:34.588596
# [700]: 2021-01-10 20:02:44.415088
# [800]: 2021-01-10 20:02:54.565187
# [900]: 2021-01-10 20:03:04.193811
# [1000]: 2021-01-10 20:03:14.499803
# [1100]: 2021-01-10 20:03:24.136592
# [1200]: 2021-01-10 20:03:33.128420
# [1300]: 2021-01-10 20:03:42.654562
# [1400]: 2021-01-10 20:03:54.358739
# [1500]: 2021-01-10 20:04:07.457265
# [1600]: 2021-01-10 20:04:18.418252
# [1700]: 2021-01-10 20:04:28.706753
# [1800]: 2021-01-10 20:04:38.056905
# [1900]: 2021-01-10 20:04:48.610938
# [2000]: 2021-01-10 20:04:59.713119
# [2100]: 2021-01-10 20:05:12.203103
# [2200]: 2021-01-10 20:05:25.769520
# [2300]: 2021-01-10 20:05:36.837422
# [2400]: 2021-01-10 20:05:50.557416
# [2500]: 2021-01-10 20:06:03.439317
# [2600]: 2021-01-10 20:06:14.054541
# [2700]: 2021-01-10 20:06:27.051826
# [2800]: 2021-01-10 20:06:36.125311
# [2900]: 2021-01-10 20:06:45.184059
# [3000]: 2021-01-10 20:06:54.690494
# [3100]: 2021-01-10 20:07:05.354951
# [3200]: 2021-01-10 20:07:15.663330
# [3300]: 2021-01-10 20:07:26.125927
# [3400]: 2021-01-10 20:07:38.512745
# [3500]: 2021-01-10 20:07:49.163507
# [3600]: 2021-01-10 20:07:58.498647
# [3700]: 2021-01-10 20:08:07.391124
# [3800]: 2021-01-10 20:08:17.635029
# [3900]: 2021-01-10 20:08:26.555029
# [4000]: 2021-01-10 20:08:36.073527
# [4100]: 2021-01-10 20:08:44.876014
# [4200]: 2021-01-10 20:08:54.161641
# [4300]: 2021-01-10 20:09:02.888838
# [4400]: 2021-01-10 20:09:11.650867
# [4500]: 2021-01-10 20:09:20.505672
# [4600]: 2021-01-10 20:09:29.316395
# [4700]: 2021-01-10 20:09:38.259406
# [4800]: 2021-01-10 20:09:47.023297
# [4900]: 2021-01-10 20:09:55.968169
# [5000]: 2021-01-10 20:10:05.265545
# [5100]: 2021-01-10 20:10:14.198533
# [5200]: 2021-01-10 20:10:23.076197
# [5300]: 2021-01-10 20:10:33.158668
# [5400]: 2021-01-10 20:10:42.269979
# [5500]: 2021-01-10 20:10:51.297287
# [5600]: 2021-01-10 20:11:00.656658
# [5700]: 2021-01-10 20:11:09.585636
# [5800]: 2021-01-10 20:11:18.878699
# [5900]: 2021-01-10 20:11:28.928364
# [6000]: 2021-01-10 20:11:37.857285
# [6100]: 2021-01-10 20:11:46.599559
# [6200]: 2021-01-10 20:11:56.531226
# [6300]: 2021-01-10 20:12:07.693478
# [6400]: 2021-01-10 20:12:17.416624
# [6500]: 2021-01-10 20:12:26.428361
# [6600]: 2021-01-10 20:12:35.556018
# [6700]: 2021-01-10 20:12:44.817294
# [6800]: 2021-01-10 20:12:53.962894
# [6900]: 2021-01-10 20:13:04.189187
# [7000]: 2021-01-10 20:13:14.327115
# [7100]: 2021-01-10 20:13:23.964313
# [7200]: 2021-01-10 20:13:32.764241
# [7300]: 2021-01-10 20:13:42.068880
# [7400]: 2021-01-10 20:13:51.926718
# [7500]: 2021-01-10 20:14:05.185064
# [7600]: 2021-01-10 20:14:14.281916
# [7700]: 2021-01-10 20:14:24.048147
# [7800]: 2021-01-10 20:14:34.241969
# [7900]: 2021-01-10 20:14:43.912269
# [8000]: 2021-01-10 20:14:53.127825
# [8100]: 2021-01-10 20:15:04.076970
# [8200]: 2021-01-10 20:15:19.208059
# [8300]: 2021-01-10 20:15:28.583359
# [8400]: 2021-01-10 20:15:39.847472
# [8500]: 2021-01-10 20:15:48.738903
# [8600]: 2021-01-10 20:15:57.548555
# [8700]: 2021-01-10 20:16:07.097890
# [8800]: 2021-01-10 20:16:16.765909
# [8900]: 2021-01-10 20:16:26.977029
# [9000]: 2021-01-10 20:16:36.101159
# [9100]: 2021-01-10 20:16:46.192952
# [9200]: 2021-01-10 20:16:56.423107
# [9300]: 2021-01-10 20:17:05.869312
# [9400]: 2021-01-10 20:17:15.983070
# [9500]: 2021-01-10 20:17:26.383108
# [9600]: 2021-01-10 20:17:36.228917
# [9700]: 2021-01-10 20:17:45.690461
# [9800]: 2021-01-10 20:17:54.790526
# [9900]: 2021-01-10 20:18:04.486956
# [10000]: 2021-01-10 20:18:14.321208
# [10100]: 2021-01-10 20:18:23.835264
# [10200]: 2021-01-10 20:18:33.482226
# [10300]: 2021-01-10 20:18:42.842201
# [10400]: 2021-01-10 20:18:52.449520
# [10500]: 2021-01-10 20:19:01.992516
# [10600]: 2021-01-10 20:19:11.672405
# [10700]: 2021-01-10 20:19:20.725517
# [10800]: 2021-01-10 20:19:29.642493
# [10900]: 2021-01-10 20:19:39.284001
# [11000]: 2021-01-10 20:19:49.845325
# [11100]: 2021-01-10 20:19:58.706019
# [11200]: 2021-01-10 20:20:07.973500
# [11300]: 2021-01-10 20:20:16.860230
# [11400]: 2021-01-10 20:20:25.731787
# [11500]: 2021-01-10 20:20:34.753270
# [11600]: 2021-01-10 20:20:43.610426
# [11700]: 2021-01-10 20:20:52.509815
# [11800]: 2021-01-10 20:21:01.368068
# [11900]: 2021-01-10 20:21:10.218770
# [12000]: 2021-01-10 20:21:19.310310
# [12100]: 2021-01-10 20:21:28.398614
# [12200]: 2021-01-10 20:21:37.272314
# [12300]: 2021-01-10 20:21:46.183426
# [12400]: 2021-01-10 20:21:55.096505
# [12500]: 2021-01-10 20:22:04.066504
# [12600]: 2021-01-10 20:22:13.563450
# [12700]: 2021-01-10 20:22:23.366417
# [12800]: 2021-01-10 20:22:33.041170
# [12900]: 2021-01-10 20:22:42.585611
# [13000]: 2021-01-10 20:22:52.048137
# [13100]: 2021-01-10 20:23:01.244697
# [13200]: 2021-01-10 20:23:10.471213
# [13300]: 2021-01-10 20:23:21.094519
# [13400]: 2021-01-10 20:23:30.685105
# [13500]: 2021-01-10 20:23:47.569722
# [13600]: 2021-01-10 20:23:58.419551
# [13700]: 2021-01-10 20:24:07.794884
# [13800]: 2021-01-10 20:24:16.962870
# [13900]: 2021-01-10 20:24:26.775429
# [14000]: 2021-01-10 20:24:35.881940
# [14100]: 2021-01-10 20:24:45.526638
# [14200]: 2021-01-10 20:24:54.847441
# [14300]: 2021-01-10 20:25:04.776085
# [14400]: 2021-01-10 20:25:14.371171
# [14500]: 2021-01-10 20:25:24.077040
# [14600]: 2021-01-10 20:25:33.621052
# [14700]: 2021-01-10 20:25:42.811534
# [14800]: 2021-01-10 20:25:52.808197
# [14900]: 2021-01-10 20:26:02.622136
# [15000]: 2021-01-10 20:26:11.688917
# [15100]: 2021-01-10 20:26:20.663473
# [15200]: 2021-01-10 20:26:29.649677
# [15300]: 2021-01-10 20:26:39.183603
# [15400]: 2021-01-10 20:26:48.977942
# [15500]: 2021-01-10 20:26:58.031395
# [15600]: 2021-01-10 20:27:07.461134
# [15700]: 2021-01-10 20:27:16.442321
# [15800]: 2021-01-10 20:27:26.162114
# [15900]: 2021-01-10 20:27:35.574108
# [16000]: 2021-01-10 20:27:44.872508
# [16100]: 2021-01-10 20:27:54.323835
# [16200]: 2021-01-10 20:28:05.042511
# [16300]: 2021-01-10 20:28:14.935896
# [16400]: 2021-01-10 20:28:24.413071
# [16500]: 2021-01-10 20:28:33.686868
# [16600]: 2021-01-10 20:28:42.522885
# [16700]: 2021-01-10 20:28:51.702170
# [16800]: 2021-01-10 20:29:00.582707
# [16900]: 2021-01-10 20:29:10.411834
# [17000]: 2021-01-10 20:29:19.760493
# [17100]: 2021-01-10 20:29:29.302364
# [17200]: 2021-01-10 20:29:38.293857
# [17300]: 2021-01-10 20:29:47.670124
# [17400]: 2021-01-10 20:29:59.400899
# [17500]: 2021-01-10 20:30:08.813169
# [17600]: 2021-01-10 20:30:18.035487
# [17700]: 2021-01-10 20:30:27.828748
# [17800]: 2021-01-10 20:30:36.679945
# [17900]: 2021-01-10 20:30:45.711505
# [18000]: 2021-01-10 20:30:55.049646
# [18100]: 2021-01-10 20:31:03.980196
# [18200]: 2021-01-10 20:31:12.926803
# [18300]: 2021-01-10 20:31:21.740819
# [18400]: 2021-01-10 20:31:30.637066
# [18500]: 2021-01-10 20:31:39.565985
# [18600]: 2021-01-10 20:31:48.376233
# [18700]: 2021-01-10 20:31:57.348750
# [18800]: 2021-01-10 20:32:06.194374
# [18900]: 2021-01-10 20:32:14.990900
# [19000]: 2021-01-10 20:32:23.931803
# [19100]: 2021-01-10 20:32:32.739286
# [19200]: 2021-01-10 20:32:41.617740
# [19300]: 2021-01-10 20:32:50.404667
# [19400]: 2021-01-10 20:32:59.218993
# [19500]: 2021-01-10 20:33:08.094710
# [19600]: 2021-01-10 20:33:16.957316
# [19700]: 2021-01-10 20:33:25.782684
# [19800]: 2021-01-10 20:33:34.609508
# [19900]: 2021-01-10 20:33:43.441447
# [20000]: 2021-01-10 20:33:52.351451
# [20100]: 2021-01-10 20:34:01.245941
# [20200]: 2021-01-10 20:34:10.171276
# [20300]: 2021-01-10 20:34:19.027167
# [20400]: 2021-01-10 20:34:27.955892
# [20500]: 2021-01-10 20:34:36.815246
# [20600]: 2021-01-10 20:34:45.784513
# [20700]: 2021-01-10 20:34:54.691720
# [20800]: 2021-01-10 20:35:03.959109
# [20900]: 2021-01-10 20:35:15.189690
# [21000]: 2021-01-10 20:35:24.932065
# [21100]: 2021-01-10 20:35:34.946655
# [21200]: 2021-01-10 20:35:45.260539
# [21300]: 2021-01-10 20:35:55.043107
# [21400]: 2021-01-10 20:36:04.695659
# [21500]: 2021-01-10 20:36:13.670997
# [21600]: 2021-01-10 20:36:22.677218
# [21700]: 2021-01-10 20:36:31.904679
# [21800]: 2021-01-10 20:36:40.911195
# [21900]: 2021-01-10 20:36:49.904702
# [22000]: 2021-01-10 20:36:59.020531
# [22100]: 2021-01-10 20:37:08.035842
# [22200]: 2021-01-10 20:37:16.953477
# [22300]: 2021-01-10 20:37:25.923160
# [22400]: 2021-01-10 20:37:34.941520
# [22500]: 2021-01-10 20:37:43.822399
# [22600]: 2021-01-10 20:37:52.828219
# [22700]: 2021-01-10 20:38:01.807359
# [22800]: 2021-01-10 20:38:10.768959
# [22900]: 2021-01-10 20:38:19.670560
# [23000]: 2021-01-10 20:38:28.655542
# [23100]: 2021-01-10 20:38:37.567066
# [23200]: 2021-01-10 20:38:46.471725
# [23300]: 2021-01-10 20:38:55.427202
# [23400]: 2021-01-10 20:39:04.356392
# [23500]: 2021-01-10 20:39:13.288468
# [23600]: 2021-01-10 20:39:22.319020
# [23700]: 2021-01-10 20:39:31.311444
# [23800]: 2021-01-10 20:39:40.236102
# [23900]: 2021-01-10 20:39:49.208932
# [24000]: 2021-01-10 20:39:58.258402
# [24100]: 2021-01-10 20:40:07.290987
# [24200]: 2021-01-10 20:40:17.102240
# [24300]: 2021-01-10 20:40:26.138735
# [24400]: 2021-01-10 20:40:35.064290
# [24500]: 2021-01-10 20:40:43.951019
# [24600]: 2021-01-10 20:40:52.900987
# [24700]: 2021-01-10 20:41:01.814710
# [24800]: 2021-01-10 20:41:10.839926
# [24900]: 2021-01-10 20:41:19.756729
# [25000]: 2021-01-10 20:41:28.724108
# [25100]: 2021-01-10 20:41:37.672507
# [25200]: 2021-01-10 20:41:46.644103
# [25300]: 2021-01-10 20:41:55.760496
# [25400]: 2021-01-10 20:42:04.700980
# [25500]: 2021-01-10 20:42:13.654052
# [25600]: 2021-01-10 20:42:22.652493
# [25700]: 2021-01-10 20:42:31.666208
# [25800]: 2021-01-10 20:42:40.636517
# [25900]: 2021-01-10 20:42:50.028637
# [26000]: 2021-01-10 20:42:59.004972
# [26100]: 2021-01-10 20:43:07.994814
# [26200]: 2021-01-10 20:43:16.950007
# [26300]: 2021-01-10 20:43:25.872699
# [26400]: 2021-01-10 20:43:34.826262
# [26500]: 2021-01-10 20:43:43.777267
# [26600]: 2021-01-10 20:43:52.801650
# [26700]: 2021-01-10 20:44:01.822247
# [26800]: 2021-01-10 20:44:10.747175
# [26900]: 2021-01-10 20:44:19.804013
# [27000]: 2021-01-10 20:44:32.981981
# [27100]: 2021-01-10 20:44:42.009393
# [27200]: 2021-01-10 20:44:50.978447
# [27300]: 2021-01-10 20:45:00.273478
# [27400]: 2021-01-10 20:45:13.246788
# [27500]: 2021-01-10 20:45:22.804103
# [27600]: 2021-01-10 20:45:31.819601
# [27700]: 2021-01-10 20:45:40.815738
# [27800]: 2021-01-10 20:45:49.834294
# [27900]: 2021-01-10 20:45:59.015387
# [28000]: 2021-01-10 20:46:08.027921
# [28100]: 2021-01-10 20:46:17.044366
# [28200]: 2021-01-10 20:46:26.044995
# [28300]: 2021-01-10 20:46:35.126893
# [28400]: 2021-01-10 20:46:44.154980
# [28500]: 2021-01-10 20:46:53.207660
# [28600]: 2021-01-10 20:47:02.192605
# [28700]: 2021-01-10 20:47:11.277302
# [28800]: 2021-01-10 20:47:20.332349
# [28900]: 2021-01-10 20:47:29.385199
# [29000]: 2021-01-10 20:47:38.393968
# [29100]: 2021-01-10 20:47:47.407905
# [29200]: 2021-01-10 20:47:56.504667
# [29300]: 2021-01-10 20:48:05.453669
# [29400]: 2021-01-10 20:48:14.432255
# [29500]: 2021-01-10 20:48:23.408944
# [29600]: 2021-01-10 20:48:32.488240
# [29700]: 2021-01-10 20:48:41.434632
# [29800]: 2021-01-10 20:48:50.462639
# [29900]: 2021-01-10 20:48:59.459400
# [30000]: 2021-01-10 20:49:08.471797
# [30100]: 2021-01-10 20:49:17.473073
# [30200]: 2021-01-10 20:49:26.623363
# [30300]: 2021-01-10 20:49:35.601100
# [30400]: 2021-01-10 20:49:44.571298
# [30500]: 2021-01-10 20:49:53.599792
# [30600]: 2021-01-10 20:50:02.644326
# [30700]: 2021-01-10 20:50:11.651967
# [30800]: 2021-01-10 20:50:20.660822
# [30900]: 2021-01-10 20:50:29.711332
# [31000]: 2021-01-10 20:50:38.732230
# [31100]: 2021-01-10 20:50:47.747929
# [31200]: 2021-01-10 20:50:56.760444
# [31300]: 2021-01-10 20:51:05.975686
# [31400]: 2021-01-10 20:51:15.006466
# [31500]: 2021-01-10 20:51:24.039701
# [31600]: 2021-01-10 20:51:33.069728
# [31700]: 2021-01-10 20:51:42.069226
# [31800]: 2021-01-10 20:51:51.038432
# [31900]: 2021-01-10 20:52:00.131297
# [32000]: 2021-01-10 20:52:09.134202
# [32100]: 2021-01-10 20:52:18.155394
# [32200]: 2021-01-10 20:52:27.166927
# [32300]: 2021-01-10 20:52:36.258516
# [32400]: 2021-01-10 20:52:45.299773
# [32500]: 2021-01-10 20:52:54.332040
# [32600]: 2021-01-10 20:53:03.391457
# [32700]: 2021-01-10 20:53:12.396023
# [32800]: 2021-01-10 20:53:21.438189
# [32900]: 2021-01-10 20:53:30.485940
# [33000]: 2021-01-10 20:53:39.480262
# [33100]: 2021-01-10 20:53:48.504159
# [33200]: 2021-01-10 20:53:57.552656
# [33300]: 2021-01-10 20:54:06.633177
# [33400]: 2021-01-10 20:54:15.670469
# [33500]: 2021-01-10 20:54:24.708283
# [33600]: 2021-01-10 20:54:33.771105
# [33700]: 2021-01-10 20:54:42.820262
# [33800]: 2021-01-10 20:54:51.800759
# [33900]: 2021-01-10 20:55:01.020684
# [34000]: 2021-01-10 20:55:10.662112
# [34100]: 2021-01-10 20:55:19.764644
# [34200]: 2021-01-10 20:55:28.805458
# [34300]: 2021-01-10 20:55:37.836367
# [34400]: 2021-01-10 20:55:46.878551
# [34500]: 2021-01-10 20:55:56.132639
# [34600]: 2021-01-10 20:56:05.403281
# [34700]: 2021-01-10 20:56:14.470477
# [34800]: 2021-01-10 20:56:23.524803
# [34900]: 2021-01-10 20:56:32.620757
# [35000]: 2021-01-10 20:56:41.683871
# [35100]: 2021-01-10 20:56:50.675443
# [35200]: 2021-01-10 20:56:59.769494
# [35300]: 2021-01-10 20:57:08.821009
# [35400]: 2021-01-10 20:57:18.032169
# [35500]: 2021-01-10 20:57:27.073074
# [35600]: 2021-01-10 20:57:36.073279
# [35700]: 2021-01-10 20:57:45.070679
# [35800]: 2021-01-10 20:57:54.126392
# [35900]: 2021-01-10 20:58:03.352304
# [36000]: 2021-01-10 20:58:12.464024
# [36100]: 2021-01-10 20:58:21.475061
# [36200]: 2021-01-10 20:58:30.540978
# [36300]: 2021-01-10 20:58:39.610300
# [36400]: 2021-01-10 20:58:48.659653
# [36500]: 2021-01-10 20:58:57.727540
# [36600]: 2021-01-10 20:59:06.858944
# [36700]: 2021-01-10 20:59:15.925022
# [36800]: 2021-01-10 20:59:25.098113
# [36900]: 2021-01-10 20:59:34.151231
# [37000]: 2021-01-10 20:59:43.208384
# [37100]: 2021-01-10 20:59:52.332174
# [37200]: 2021-01-10 21:00:01.449678
# [37300]: 2021-01-10 21:00:10.572259
# [37400]: 2021-01-10 21:00:19.640297
# [37500]: 2021-01-10 21:00:28.738380
# [37600]: 2021-01-10 21:00:37.823569
# [37700]: 2021-01-10 21:00:47.094100
# [37800]: 2021-01-10 21:00:56.234939
# [37900]: 2021-01-10 21:01:05.358977
# [38000]: 2021-01-10 21:01:14.459076
# [38100]: 2021-01-10 21:01:23.548167
# [38200]: 2021-01-10 21:01:32.690530
# [38300]: 2021-01-10 21:01:41.858573
# [38400]: 2021-01-10 21:01:50.955246
# [38500]: 2021-01-10 21:02:00.116824
# [38600]: 2021-01-10 21:02:09.181059
# [38700]: 2021-01-10 21:02:18.275983
# [38800]: 2021-01-10 21:02:27.422504
# [38900]: 2021-01-10 21:02:36.512775
# [39000]: 2021-01-10 21:02:45.649784
# [39100]: 2021-01-10 21:02:54.773862
# [39200]: 2021-01-10 21:03:04.016520
# [39300]: 2021-01-10 21:03:13.139351
# [39400]: 2021-01-10 21:03:22.236048
# [39500]: 2021-01-10 21:03:31.334802
# [39600]: 2021-01-10 21:03:40.599616
# [39700]: 2021-01-10 21:03:49.705028
# [39800]: 2021-01-10 21:03:58.926392
# [39900]: 2021-01-10 21:04:08.038725
# [40000]: 2021-01-10 21:04:17.182488
# [40100]: 2021-01-10 21:04:26.386127
# [40200]: 2021-01-10 21:04:35.554498
# [40300]: 2021-01-10 21:04:44.715651
# [40400]: 2021-01-10 21:04:53.848136
# [40500]: 2021-01-10 21:05:08.899429
# [40600]: 2021-01-10 21:05:18.294830
# [40700]: 2021-01-10 21:05:27.440254
# [40800]: 2021-01-10 21:05:36.573536
# [40900]: 2021-01-10 21:05:45.681764
# [41000]: 2021-01-10 21:05:54.890557
# [41100]: 2021-01-10 21:06:04.187593
# [41200]: 2021-01-10 21:06:13.849390
# [41300]: 2021-01-10 21:06:23.835925
# [41400]: 2021-01-10 21:06:33.835037
# [41500]: 2021-01-10 21:06:44.157873
# [41600]: 2021-01-10 21:06:54.302704
# [41700]: 2021-01-10 21:07:03.777158
# [41800]: 2021-01-10 21:07:12.932413
# [41900]: 2021-01-10 21:07:22.163736
# [42000]: 2021-01-10 21:07:31.747684
# [42100]: 2021-01-10 21:07:40.938689
# [42200]: 2021-01-10 21:16:42.433999
# [42300]: 2021-01-10 21:16:56.937214
# [42400]: 2021-01-10 21:17:07.300888
# [42500]: 2021-01-10 21:17:17.569864
# [42600]: 2021-01-10 21:17:28.231084
# [42700]: 2021-01-10 21:17:38.049913
# [42800]: 2021-01-10 21:17:48.047234
# [42900]: 2021-01-10 21:17:57.432291
# [43000]: 2021-01-10 21:18:06.828394
# [43100]: 2021-01-10 21:18:18.146355
# [43200]: 2021-01-10 21:18:29.189375
# [43300]: 2021-01-10 21:18:39.934904
# [43400]: 2021-01-10 21:18:50.655241
# [43500]: 2021-01-10 21:19:01.915524
# [43600]: 2021-01-10 21:19:12.560548
# [43700]: 2021-01-10 21:19:23.416122
# [43800]: 2021-01-10 21:19:32.864338
# [43900]: 2021-01-10 21:19:42.474295
# [44000]: 2021-01-10 21:19:52.097878
# [44100]: 2021-01-10 21:20:01.958126
# [44200]: 2021-01-10 21:20:11.833957
# [44300]: 2021-01-10 21:20:21.880759
# [44400]: 2021-01-10 21:20:31.706326
# [44500]: 2021-01-10 21:20:41.345792
# [44600]: 2021-01-10 21:20:52.157721
# [!] End Loading: 2021-01-10 21:20:52.561021
# [!] Start save: 2021-01-10 21:20:52.561719
# [!] Start save: 2021-01-10 21:21:30.900084

# %%
print(f"[!] Start Loading: {datetime.now()}")
gdf_point_not_found = gpd.GeoDataFrame()

i = 0 

for idx, row in df_risk.iterrows():
    node_id, distance = ox.get_nearest_node(G, (row["latitude"], row["longitude"]), return_dist=True)
    if distance >= 10:
        gdf_point_not_found = gdf_point_not_found.append(row)
    if idx % 100 == 0:
        print(f"[{idx}]: {datetime.now()}") 
    
print(f"[!] End Loading: {datetime.now()}") 
print(f"[!] Start save: {datetime.now()}")  
#ox.save_graphml(G, filepath="NYC_drive_risk.osm")
gdf_point_not_found.to_csv('point_not_found.csv')
print(f"[!] End save: {datetime.now()}")
# Out:
# [!] Start Loading: 2021-01-10 22:30:33.431307
# [0]: 2021-01-10 22:30:38.422877
# [100]: 2021-01-10 22:30:52.737558
# [200]: 2021-01-10 22:31:04.337042
# [300]: 2021-01-10 22:31:17.961289
# [400]: 2021-01-10 22:31:29.623632
# [500]: 2021-01-10 22:31:40.580037
# [600]: 2021-01-10 22:31:53.429387
# [700]: 2021-01-10 22:32:05.921280
# [800]: 2021-01-10 22:32:23.825814
# [900]: 2021-01-10 22:32:39.939712
# [1000]: 2021-01-10 22:32:57.467877
# [1100]: 2021-01-10 22:33:13.596804
# [1200]: 2021-01-10 22:33:29.256879
# [1300]: 2021-01-10 22:33:56.385956
# [1400]: 2021-01-10 22:34:30.317225
# [1500]: 2021-01-10 22:34:52.505580
# [1600]: 2021-01-10 22:35:14.972280
# [1700]: 2021-01-10 22:35:38.835433
# [1800]: 2021-01-10 22:36:06.903337
# [1900]: 2021-01-10 22:36:35.209594
# [2000]: 2021-01-10 22:37:05.696567
# [2100]: 2021-01-10 22:37:31.719835
# [2200]: 2021-01-10 22:38:00.781049
# [2300]: 2021-01-10 22:38:27.051653
# [2400]: 2021-01-10 22:39:21.456885
# [2500]: 2021-01-10 22:39:43.272975
# [2600]: 2021-01-10 22:40:07.480667
# [2700]: 2021-01-10 22:40:31.824948
# [2800]: 2021-01-10 22:40:58.576643
# [2900]: 2021-01-10 22:41:21.104430
# [3000]: 2021-01-10 22:41:52.940037
# [3100]: 2021-01-10 22:42:46.080471
# [3200]: 2021-01-10 22:43:15.578631
# [3300]: 2021-01-10 22:43:44.778037
# [3400]: 2021-01-10 22:44:19.303335
# [3500]: 2021-01-10 22:44:50.728546
# [3600]: 2021-01-10 22:45:35.330604
# [3700]: 2021-01-10 22:46:07.522366
# [3800]: 2021-01-10 22:46:45.653372
# [3900]: 2021-01-10 22:47:22.821705
# [4000]: 2021-01-10 22:47:51.234644
# [4100]: 2021-01-10 22:48:40.896271
# [4200]: 2021-01-10 22:49:11.817976
# [4300]: 2021-01-10 22:49:47.294761
# [4400]: 2021-01-10 22:50:18.082170
# [4500]: 2021-01-10 22:50:53.655368
# [4600]: 2021-01-10 22:51:52.804239
# [4700]: 2021-01-10 22:52:42.963403
# [4800]: 2021-01-10 22:53:21.615643
# [4900]: 2021-01-10 22:54:35.712248
# [5000]: 2021-01-10 22:55:25.225657
# [5100]: 2021-01-10 22:56:09.919438
# [5200]: 2021-01-10 22:56:56.674929
# [5300]: 2021-01-10 22:57:32.722111
# [5400]: 2021-01-10 22:58:16.108256
# [5500]: 2021-01-10 23:02:26.705451
# [5600]: 2021-01-10 23:03:05.504459
# [5700]: 2021-01-10 23:03:40.608233
# [5800]: 2021-01-10 23:04:13.988033
# [5900]: 2021-01-10 23:04:47.100163
# [6000]: 2021-01-10 23:05:21.072129
# [6100]: 2021-01-10 23:05:53.169289
# [6200]: 2021-01-10 23:06:33.864565
# [6300]: 2021-01-10 23:07:04.610371
# [6400]: 2021-01-10 23:07:38.426040
# [6500]: 2021-01-10 23:08:08.687015
# [6600]: 2021-01-10 23:08:43.763086
# [6700]: 2021-01-10 23:09:15.598616
# [6800]: 2021-01-10 23:09:50.804060
# [6900]: 2021-01-10 23:10:25.279425
# [7000]: 2021-01-10 23:11:01.079021
# [7100]: 2021-01-10 23:11:41.168617
# [7200]: 2021-01-10 23:12:19.143715
# [7300]: 2021-01-10 23:12:59.898288
# [7400]: 2021-01-10 23:13:34.343873
# [7500]: 2021-01-10 23:14:11.938607
# [7600]: 2021-01-10 23:14:51.358548
# [7700]: 2021-01-10 23:15:35.198466
# [7800]: 2021-01-10 23:16:11.984971
# [7900]: 2021-01-10 23:16:52.445422
# [8000]: 2021-01-10 23:17:32.711808
# [8100]: 2021-01-10 23:18:13.057441
# [8200]: 2021-01-10 23:19:00.021180
# [8300]: 2021-01-10 23:20:05.625968
# [8400]: 2021-01-10 23:20:59.625220
# [8500]: 2021-01-10 23:21:41.971254
# [8600]: 2021-01-10 23:22:25.813350
# [8700]: 2021-01-10 23:23:14.283163
# [8800]: 2021-01-10 23:23:54.326868
# [8900]: 2021-01-10 23:24:47.789060
# [9000]: 2021-01-10 23:25:34.772085
# [9100]: 2021-01-10 23:26:12.976330
# [9200]: 2021-01-10 23:27:02.178724
# [9300]: 2021-01-10 23:27:47.769211
# [9400]: 2021-01-10 23:28:40.319194
# [9500]: 2021-01-10 23:29:24.926623
# [9600]: 2021-01-10 23:30:16.442325
# [9700]: 2021-01-10 23:31:16.123114
# [9800]: 2021-01-10 23:32:07.730097
# [9900]: 2021-01-10 23:32:55.611789
# [10000]: 2021-01-10 23:33:44.825674
# [10100]: 2021-01-10 23:34:38.709952
# [10200]: 2021-01-10 23:35:28.076627
# [10300]: 2021-01-10 23:36:21.897519
# [10400]: 2021-01-10 23:37:25.314759
# [10500]: 2021-01-10 23:38:11.370022
# [10600]: 2021-01-10 23:39:01.387425
# [10700]: 2021-01-10 23:40:12.975871
# [10800]: 2021-01-10 23:41:07.631297
# [10900]: 2021-01-10 23:42:00.074004
# [11000]: 2021-01-10 23:42:52.220612
# [11100]: 2021-01-10 23:43:54.715492
# [11200]: 2021-01-10 23:44:50.092314
# [11300]: 2021-01-10 23:45:44.698625
# [11400]: 2021-01-10 23:46:45.936276
# [11500]: 2021-01-10 23:47:48.224411
# [11600]: 2021-01-10 23:48:48.049133
# [11700]: 2021-01-10 23:49:57.627010
# [11800]: 2021-01-10 23:51:10.349316
# [11900]: 2021-01-10 23:52:16.278062
# [12000]: 2021-01-10 23:53:11.951844
# [12100]: 2021-01-10 23:54:34.184616
# [12200]: 2021-01-10 23:55:58.090479
# [12300]: 2021-01-10 23:57:15.887372
# [12400]: 2021-01-10 23:58:37.136767
# [12500]: 2021-01-10 23:59:54.346622
# [12600]: 2021-01-11 00:01:01.607987
# [12700]: 2021-01-11 00:02:03.057012
# [12800]: 2021-01-11 00:03:19.219418
# [12900]: 2021-01-11 00:04:46.847854
# [13000]: 2021-01-11 00:06:03.695822
# [13100]: 2021-01-11 00:07:30.956222
# [13200]: 2021-01-11 00:08:23.954085
# [13300]: 2021-01-11 00:09:27.429207
# [13400]: 2021-01-11 00:10:28.792407
# [13500]: 2021-01-11 00:11:44.848962
# [13600]: 2021-01-11 00:13:01.395994
# [13700]: 2021-01-11 00:14:12.774431
# [13800]: 2021-01-11 00:15:13.602452
# [13900]: 2021-01-11 00:16:21.960913
# [14000]: 2021-01-11 00:17:35.464361
# [14100]: 2021-01-11 00:18:29.452693
# [14200]: 2021-01-11 00:19:39.396860
# [14300]: 2021-01-11 00:20:39.515021
# [14400]: 2021-01-11 00:21:47.442448
# [14500]: 2021-01-11 00:23:11.148888
# [14600]: 2021-01-11 00:24:22.860463
# [14700]: 2021-01-11 00:25:29.202890
# [14800]: 2021-01-11 00:26:26.985645
# [14900]: 2021-01-11 00:27:34.921585
# [15000]: 2021-01-11 00:28:35.445753
# [15100]: 2021-01-11 00:30:01.136794
# [15200]: 2021-01-11 00:31:16.699383
# [15300]: 2021-01-11 00:32:25.310990
# [15400]: 2021-01-11 00:33:35.987499
# [15500]: 2021-01-11 00:34:43.855299
# [15600]: 2021-01-11 00:35:48.167340
# [15700]: 2021-01-11 00:36:52.825547
# [15800]: 2021-01-11 00:37:58.226108
# [15900]: 2021-01-11 00:38:57.213239
# [16000]: 2021-01-11 00:40:05.625275
# [16100]: 2021-01-11 00:41:21.660697
# [16200]: 2021-01-11 00:42:18.320751
# [16300]: 2021-01-11 00:43:22.327951
# [16400]: 2021-01-11 00:44:40.438651
# [16500]: 2021-01-11 00:45:42.374051
# [16600]: 2021-01-11 00:46:52.094852
# [16700]: 2021-01-11 00:48:00.630567
# [16800]: 2021-01-11 00:49:12.183377
# [16900]: 2021-01-11 00:50:14.623876
# [17000]: 2021-01-11 00:51:36.775058
# [17100]: 2021-01-11 00:52:41.701296
# [17200]: 2021-01-11 00:53:44.585280
# [17300]: 2021-01-11 00:55:04.491243
# [17400]: 2021-01-11 00:56:08.639412
# [17500]: 2021-01-11 00:57:14.726784
# [17600]: 2021-01-11 00:58:20.268161
# [17700]: 2021-01-11 00:59:33.329878
# [17800]: 2021-01-11 01:00:30.687601
# [17900]: 2021-01-11 01:01:41.927865
# [18000]: 2021-01-11 01:02:43.618789
# [18100]: 2021-01-11 01:03:56.743770
# [18200]: 2021-01-11 01:05:01.460298
# [18300]: 2021-01-11 01:06:07.443339
# [18400]: 2021-01-11 01:07:29.155941
# [18500]: 2021-01-11 01:08:39.453698
# [18600]: 2021-01-11 01:09:36.633436
# [18700]: 2021-01-11 01:10:44.808136
# [18800]: 2021-01-11 01:11:48.682892
# [18900]: 2021-01-11 01:18:16.356345
# [19000]: 2021-01-11 01:19:45.646780
# [19100]: 2021-01-11 01:21:38.544222
# [19200]: 2021-01-11 01:22:48.081213
# [19300]: 2021-01-11 01:24:05.852952
# [19400]: 2021-01-11 01:25:36.279798
# [19500]: 2021-01-11 01:27:03.842257
# [19600]: 2021-01-11 01:29:09.291552
# [19700]: 2021-01-11 01:30:56.131777
# [19800]: 2021-01-11 01:32:56.948626
# [19900]: 2021-01-11 01:34:40.796953
# [20000]: 2021-01-11 01:36:28.884303
# [20100]: 2021-01-11 01:38:29.547921
# [20200]: 2021-01-11 01:40:24.713849
# [20300]: 2021-01-11 01:42:20.833898
# [20400]: 2021-01-11 01:44:12.476927
# [20500]: 2021-01-11 01:45:51.413992
# [20600]: 2021-01-11 01:47:44.256955
# [20700]: 2021-01-11 01:50:30.090606
# [20800]: 2021-01-11 01:52:50.652464
# [20900]: 2021-01-11 01:54:45.144355
# [21000]: 2021-01-11 01:55:59.566023
# [21100]: 2021-01-11 01:57:45.841660
# [21200]: 2021-01-11 01:59:08.421320
# [21300]: 2021-01-11 02:00:51.546728
# [21400]: 2021-01-11 08:04:16.688523
# [21500]: 2021-01-11 08:06:07.158048
# [21600]: 2021-01-11 08:07:47.090774
# [21700]: 2021-01-11 08:09:26.302113
# [21800]: 2021-01-11 08:10:41.168429
# [21900]: 2021-01-11 08:12:20.053152
# [22000]: 2021-01-11 08:14:08.945387
# [22100]: 2021-01-11 08:15:45.514407
# [22200]: 2021-01-11 08:17:57.787106
# [22300]: 2021-01-11 08:20:06.224903
# [22400]: 2021-01-11 08:22:12.339705
# [22500]: 2021-01-11 08:24:37.442809
# [22600]: 2021-01-11 08:26:32.604187
# [22700]: 2021-01-11 08:29:00.603351
# [22800]: 2021-01-11 08:31:57.358754
# [22900]: 2021-01-11 08:34:24.519260
# [23000]: 2021-01-11 08:37:04.226952
# [23100]: 2021-01-11 08:39:27.087447
# [23200]: 2021-01-11 08:43:28.649347
# [23300]: 2021-01-11 08:45:56.041341
# [23400]: 2021-01-11 08:48:04.529982
# [23500]: 2021-01-11 08:50:09.943663
# [23600]: 2021-01-11 08:52:04.103454
# [23700]: 2021-01-11 08:54:33.920305
# [23800]: 2021-01-11 08:56:20.081634
# [23900]: 2021-01-11 08:57:54.842999
# [24000]: 2021-01-11 09:00:15.495732
# [24100]: 2021-01-11 09:04:59.311333
# [24200]: 2021-01-11 09:08:23.754818
# [24300]: 2021-01-11 09:11:59.094989
# [24400]: 2021-01-11 09:15:05.380909
# [24500]: 2021-01-11 09:19:24.160992
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-0cc286ff98cb> in <module>
#       5
#       6 for idx, row in df_risk.iterrows():
# ----> 7     node_id, distance = ox.get_nearest_node(G, (row["latitude"], row["longitude"]), return_dist=True)
#       8     if distance >= 10:
#       9         gdf_point_not_found = gdf_point_not_found.append(row)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/osmnx/distance.py in get_nearest_node(G, point, method, return_dist)
#     136     # with x and y columns
#     137     coords = ((n, d["x"], d["y"]) for n, d in G.nodes(data=True))
# --> 138     df = pd.DataFrame(coords, columns=["node", "x", "y"]).set_index("node")
#     139
#     140     # add columns to df for the (constant) coordinates of reference point
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     526         return [], []  # columns if columns is not None else []
#     527     if isinstance(data[0], (list, tuple)):
# --> 528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
#     530         return _list_of_dict_to_arrays(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
#     568         columns = _validate_or_indexify_columns(content, columns)
# --> 569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     570     except AssertionError as e:
#     571         raise ValueError(e) from e
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, coerce_float, dtype)
#     734         return arr
#     735
# --> 736     arrays = [convert(arr) for arr in content]
#     737
#     738     return arrays
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in <listcomp>(.0)
#     734         return arr
#     735
# --> 736     arrays = [convert(arr) for arr in content]
#     737
#     738     return arrays
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in convert(arr)
#     730     def convert(arr):
#     731         if dtype != np.dtype("O"):
# --> 732             arr = lib.maybe_convert_objects(arr, try_float=coerce_float)
#     733             arr = maybe_cast_to_datetime(arr, dtype)
#     734         return arr
#
# KeyboardInterrupt:

# %%
gdf_point_not_found.shape
# Out:
# (13096, 6)

# %%
gdf_point_not_found.to_csv('point_not_found.csv')
